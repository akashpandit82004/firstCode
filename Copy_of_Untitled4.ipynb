# %% [markdown]
# <a href="https://colab.research.google.com/github/akashpandit82004/firstCode/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("vggg")
# Out:
# vggg
